# %% [markdown]
# # Lab | Data Structures

# %% [markdown]
# ## Exercise: Managing Customer Orders
#
# As part of a business venture, you are starting an online store that sells various products. To ensure smooth operations, you need to develop a program that manages customer orders and inventory.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a list called `products` that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".
#
# 2. Create an empty dictionary called `inventory`.
#
# 3. Ask the user to input the quantity of each product available in the inventory. Use the product names from the `products` list as keys in the `inventory` dictionary and assign the respective quantities as values.
#
# 4. Create an empty set called `customer_orders`.
#
# 5. Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the `customer_orders` set.
#
# 6. Print the products in the `customer_orders` set.
#
# 7. Calculate the following order statistics:
#    - Total Products Ordered: The total number of products in the `customer_orders` set.
#    - Percentage of Products Ordered: The percentage of products ordered compared to the total available products.
#
#    Store these statistics in a tuple called `order_status`.
#
# 8. Print the order statistics using the following format:
#    ```
#    Order Statistics:
#    Total Products Ordered: <total_products_ordered>
#    Percentage of Products Ordered: <percentage_ordered>%
#    ```
#
# 9. Update the inventory by subtracting 1 from the quantity of each product. Modify the `inventory` dictionary accordingly.
#
# 10. Print the updated inventory, displaying the quantity of each product on separate lines.
#
# Solve the exercise by implementing the steps using the Python concepts of lists, dictionaries, sets, and basic input/output operations.

# %%
#Define a list called products that contains the following items: "t-shirt", "mug", "hat", "book", "keychain"
products=['t-shirt', 'mug', 'hat', 'book', 'keychain']
#Create an empty dictionary called inventory.
inventory={}

#Ask the user to input the quantity of each product available in the inventory. Use the product names from the 
#products list as keys in the inventory dictionary and assign the respective quantities as values.
for item in products:
    inventory[item]=int(input(f'Enter the quantity of the product {item} '))
    
print (inventory)

#Create an empty set called customer_orders.
customer_orders={'t-shirt': 0, 'mug': 0, 'hat': 0, 'book': 0, 'keychain': 0}
order='yes'

#Ask the user to input the name of three products that a customer wants to order (from those in the products list, 
#meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the customer_orders set.
while order=='yes':
    user_input=input('Enter the numero of the product you want to order: 1.t-shirt 2.mug 3.hat 4.book 5.keychain')
    if user_input=='1':
        customer_orders['t-shirt']+=int(input('Quantity:'))            
        order=input('Do you want to order another item? Enter yes or no ')
    elif user_input=='2':
        customer_orders['mug']+=int(input('Quantity:'))
        order=input('Do you want to order another item? Enter yes or no ')
    elif user_input=='3':
        customer_orders['hat']+=int(input('Quantity:'))
        order=input('Do you want to order another item? Enter yes or no ')
    elif user_input=='4':
        customer_orders['book']+=int(input('Quantity:'))
        order=input('Do you want to order another item? Enter yes or no ')
    elif user_input=='5':
        customer_orders['keychain']+=int(input('Quantity:'))
        order=input('Do you want to order another item? Enter yes or no ')
        
#Print the products in the customer_orders set.
print('\n')
print(customer_orders)
print('\n')
#Calculate the following order statistics:
total_products_ordered=[]
for value in customer_orders.values():
    total_products_ordered.append(value)

print('Total Products Ordered: ',sum(total_products_ordered))    
print('\n')
for product in inventory:
    if customer_orders.get(product)==0:
        print(f'The % of the product {product} is 0')
    elif inventory[product]== customer_orders.get(product):
        print(f'The % of the product {product} is 100')
        inventory[product]=(inventory.get(product)-customer_orders[product])
    elif inventory[product]!= customer_orders.get(product):
        print (f'The % of the product {product} is ',(customer_orders[product]/inventory.get(product))*100)
        inventory[product]=(inventory.get(product)-customer_orders[product])
print('\n')
print('Inventory updated: ',inventory)
print('\n')
#Update the inventory by subtracting 1 from the quantity of each product. Modify the inventory dictionary accordingly.
for product in inventory:
    inventory[product]-=1
print('\n')
print('Inventory updated subtracting 1: ')

for key, value in inventory.items():
    print (key)
    print(value)
# Out:
# Enter the quantity of the product t-shirt 100
# Enter the quantity of the product mug 25
# Enter the quantity of the product hat 50
# Enter the quantity of the product book 99
# Enter the quantity of the product keychain 125
# {'t-shirt': 100, 'mug': 25, 'hat': 50, 'book': 99, 'keychain': 125}
# Enter the numero of the product you want to order: 1.t-shirt 2.mug 3.hat 4.book 5.keychain1
# Quantity:50
# Do you want to order another item? Enter yes or no yes
# Enter the numero of the product you want to order: 1.t-shirt 2.mug 3.hat 4.book 5.keychain2
# Quantity:30
# Do you want to order another item? Enter yes or no yes
# Enter the numero of the product you want to order: 1.t-shirt 2.mug 3.hat 4.book 5.keychain5
# Quantity:123
# Do you want to order another item? Enter yes or no no
#
#
# {'t-shirt': 50, 'mug': 30, 'hat': 0, 'book': 0, 'keychain': 123}
#
#
# Total Products Ordered:  203
#
#
# The % of the product t-shirt is  50.0
# The % of the product mug is  120.0
# The % of the product hat is 0
# The % of the product book is 0
# The % of the product keychain is  98.4
#
#
# Inventory updated:  {'t-shirt': 50, 'mug': -5, 'hat': 50, 'book': 99, 'keychain': 2}
#
#
#
#
# Inventory updated subtracting 1:
# t-shirt
# 49
# mug
# -6
# hat
# 49
# book
# 98
# keychain
# 1
